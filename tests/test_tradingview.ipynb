# %%
import pandas as pd
def parse(path):
        sector_data_frame = pd.read_csv(path)
        for index, row in sector_data_frame.iterrows():
            exchange = row['Exchange']
            symbol = '{:06d}'.format(row['Ticker'])
            Sector = row['Sector']
            print(symbol)
        return sector_data_frame

parse('/Users/line/Downloads/china_2021-03-12.csv')
# Out:
# 600519
# 601398
# 601939
# 601318
# 600036
# 601288
# 000858
# 601988
# 601628
# 601658
# 601857
# 300750
# 601888
# 000333
# 600028
# 002415
# 002594
# 603288
# 600276
# 601166
# 600900
# 300760
# 300999
# 688981
# 603259
# 002352
# 601601
# 000001
# 002714
# 601088
# 000002
# 601995
# 000651
# 601328
# 600309
# 601012
# 600031
# 600000
# 600030
# 002475
# 000568
# 601633
# 601816
# 601138
# 600585
# 601899
# 601319
# 601998
# 601066
# 300122
# 002304
# 600809
# 300059
# 300015
# 600104
# 600887
# 600346
# 600016
# 002142
# 601818
# 603501
# 000725
# 601668
# 600690
# 002493
# 002607
# 601766
# 600019
# 600048
# 600999
# 000661
# 000338
# 000538
# 601336
# 600436
# 688036
# 002027
# 600837
# 601688
# 600438
# 300014
# 300124
# 688111
# 000063
# 000895
# 601211
# 300433
# 003816
# 601390
# 000708
# 600050
# 688185
# 600893
# 002460
# 000100
# 603993
# 600745
# 601919
# 600406
# 600703
# 002311
# 601100
# 601229
# 000776
# 600660
# 601111
# 000166
# 601238
# 002736
# 601800
# 600588
# ...
