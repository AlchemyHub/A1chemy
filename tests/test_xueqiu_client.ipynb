# %%
import requests


headers = {
                'Connection': 'keep-alive',
                'Accept': '*/*',
                'cache-control': 'no-cache',
                'X-Requested-With': 'XMLHttpRequest',
                'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 11_0_0) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/86.0.4240.193 Safari/537.36',
                'Sec-Fetch-Site': 'same-origin',
                'Sec-Fetch-Mode': 'cors',
                'Sec-Fetch-Dest': 'empty',
                'Referer': 'https://xueqiu.com',
                'Accept-Language': 'en,zh-CN;q=0.9,zh;q=0.8,zh-TW;q=0.7',
            }

response = requests.get('https://xueqiu.com/', headers=headers)
response.cookies
# Out:
# <RequestsCookieJar[Cookie(version=0, name='u', value='381607872706342', port=None, port_specified=False, domain='.xueqiu.com', domain_specified=True, domain_initial_dot=True, path='/', path_specified=True, secure=False, expires=None, discard=True, comment=None, comment_url=None, rest={}, rfc2109=False), Cookie(version=0, name='xq_a_token', value='1132205e8c57eb587b26526804cff9f3b6bf6799', port=None, port_specified=False, domain='.xueqiu.com', domain_specified=True, domain_initial_dot=True, path='/', path_specified=True, secure=False, expires=None, discard=True, comment=None, comment_url=None, rest={'httponly': None}, rfc2109=False), Cookie(version=0, name='xq_id_token', value='eyJ0eXAiOiJKV1QiLCJhbGciOiJSUzI1NiJ9.eyJ1aWQiOi0xLCJpc3MiOiJ1YyIsImV4cCI6MTYwOTEyMzA1NywiY3RtIjoxNjA3ODcyNjgxNzA2LCJjaWQiOiJkOWQwbjRBWnVwIn0.f9uS_lfyP4FYT4MrnlbrcR1oDvVcXUsRrTM7gHK-j-pGmctR-ZBNy-l7FKnYfpgV7vbgTfQXQaahTw4HDGVaQ1zH1jhmDWcjTiyJ1QNAlWm4GAj47HM4_YSogTPNOJc0LVScJ9VRw7YsdmPfTSXRC8RaaMifdi6BvLWa4iF7IB4GYkZlw5mIKa9_zRXwEqM4hJ0-KHU-McO9TB0dd0LkCBI4m3_oDMQZ7rCIgK5y5gNpRFATvzrULDRUJ4Q8p_JZFWJO5K_tIk5qTFXsgRsxzBBoOBNnrt9JawiumAO4iS6IZPzyZXi0UmEB3ExT9TDSGZHN33tOhpiAYfWIgg3DVg', port=None, port_specified=False, domain='.xueqiu.com', domain_specified=True, domain_initial_dot=True, path='/', path_specified=True, secure=False, expires=None, discard=True, comment=None, comment_url=None, rest={'httponly': None}, rfc2109=False), Cookie(version=0, name='xq_r_token', value='81b9c911ea3907729d8f8e9f60d9f5251227c551', port=None, port_specified=False, domain='.xueqiu.com', domain_specified=True, domain_initial_dot=True, path='/', path_specified=True, secure=False, expires=None, discard=True, comment=None, comment_url=None, rest={'httponly': None}, rfc2109=False), Cookie(version=0, name='xqat', value='1132205e8c57eb587b26526804cff9f3b6bf6799', port=None, port_specified=False, domain='.xueqiu.com', domain_specified=True, domain_initial_dot=True, path='/', path_specified=True, secure=False, expires=None, discard=True, comment=None, comment_url=None, rest={'httponly': None}, rfc2109=False)]>

# %%
import a1chemy.data_source as data_source
xueqiu_client = data_source.XueQiuDataParser(cookies=response.cookies)

# %%
xueqiu_client.history(symbol='SH510050', exchange='SH', period = 'day').raw_data
# Out:
#                          time     volume    open    high     low   close
# 0   2018-03-12 00:00:00+08:00  524250859  2.7722  2.7789  2.7513  2.7618
# 1   2018-03-13 00:00:00+08:00  611026319  2.7627  2.7722  2.7275  2.7313
# 2   2018-03-14 00:00:00+08:00  307910846  2.7228  2.7323  2.7123  2.7218
# 3   2018-03-15 00:00:00+08:00  332744795  2.7152  2.7485  2.7114  2.7475
# 4   2018-03-16 00:00:00+08:00  429644043  2.7485  2.7618  2.7199  2.7209
# ..                        ...        ...     ...     ...     ...     ...
# 667 2020-12-07 00:00:00+08:00  486309440  3.5440  3.5490  3.4920  3.5110
# 668 2020-12-08 00:00:00+08:00  436983773  3.5800  3.5800  3.4880  3.4990
# 669 2020-12-09 00:00:00+08:00  512286103  3.5070  3.5200  3.4650  3.4700
# 670 2020-12-10 00:00:00+08:00  458333410  3.4610  3.4770  3.4390  3.4560
# 671 2020-12-11 00:00:00+08:00  540670655  3.4690  3.4780  3.4030  3.4290
#
# [672 rows x 6 columns]
